# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]

# %%
if 5 > 2:
    print("five is grater than two")
# Out:
# five is grater than two

# %%
x = 5
y = "Hello World!"

# %%
#comment
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Python is fun!")
# Out:
# Python is fun!

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %%
print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %%
print("This will work!")
print('This will also work!')
# Out:
# This will work!
# This will also work!

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
print(3 + 3)
print(2 * 5)
# Out:
# 6
# 10

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %%
x = 5
y = "Akniet"
print(x)
print(y)
# Out:
# 5
# Akniet

# %%
x = 4       # x is of type int
x = "kbtu" # x is now of type str
print(x)
# Out:
# kbtu

# %%
x = str(3)   #x is "3" 
y = int(3)    #y is 3
z = float(3)  #z is 3.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
myvar = 'ak'
my_var = 'ak'
_my_var = 'ak'
myVar = 'ak'
MYVAR = 'ak'
myvar2 = 'ak'

# %%
myVarName = 'ak' #camel case
MyVarName = 'ak' #pascal case
my_var_name = 'ak' #snake case

# %%
x, y, z = 'a', 'b', 'c'
print(x)
print(y)
print(z)
# Out:
# a
# b
# c

# %%
x = y = z = "a"
print(x)
print(y)
print(z)
# Out:
# a
# a
# a

# %%
letters = ['a' , 'b', 'c']
x, y, z = letters
print(x)
print(y)
print(z)
# Out:
# a
# b
# c

# %%
x = 'kbtu'
print(x)
# Out:
# kbtu

# %%
x = 'kbtu'
y = 'is'
z = 'cool'
print (x , y , z)
# Out:
# kbtu is cool

# %%
x = 'kbtu'
y = 'is'
z = 'cool'
print (x + y + z)
# Out:
# kbtuiscool

# %%
x = 5
y = 10
print (x + y)
# Out:
# 15

# %%
x = 5
y = 'a'
print(x , y)
# Out:
# 5 a

# %%
x = 'a'
def func():
    print("my name starts with " + x)
func()
# Out:
# my name starts with a

# %%
x = 'good'
def func():
    x = 'great'
    print('kbtu is ' + x)
func()
print('kbtu is ' + x)
# Out:
# kbtu is great
# kbtu is good

# %%
def var():
    global x
    x = 'abc'
var()
print('alphabet: ' + x)
# Out:
# alphabet: abc

# %%
x = 'xyz'
def var():
    global x
    x = 'abc'
var()
print('alphabet: ' + x)
# Out:
# alphabet: abc

# %%
x = 6
print(type(x))
# Out:
# <class 'int'>

# %%
x = 6.3
print(type(x))
# Out:
# <class 'float'>

# %%
x = 1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = 'a'
print(type(x))
# Out:
# <class 'str'>

# %%
x = ['a', 'b']
print(type(x))
# Out:
# <class 'list'>

# %%
x = ('a', 'b')
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = {'a', 'b'}
print(type(x))
# Out:
# <class 'set'>

# %%
x = {'name' : 'akniet' , 'age' : 18}
print(type(x))
# Out:
# <class 'dict'>

# %%
x = frozenset({'a', 'b'})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = range(6)
print(type(x))
# Out:
# <class 'range'>

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
x = b"Hello"
print(type(x))
# Out:
# <class 'bytes'>

# %%
x = bytearray(5)
print(type(x))
# Out:
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
x = 1
y = 2.7
z = 3j

a = float(x)
b = int(y)
c = complex(z)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# 3j
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
import random
print(random.randrange(1,10))
# Out:
# 3

# %%
a = '''a
b
c'''
print(a)
b = """a
b
c"""
print(b)
# Out:
# a
# b
# c
# a
# b
# c

# %%
a = 'akniet blue'
print(a[1])
# Out:
# k

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a = 'akniet is the best'
print(len(a))
# Out:
# 18

# %%
txt = "i love kbtu"
print("free" in txt)
# Out:
# False

# %%
txt = "i love kbtu"
if "love" in txt:
    print("love is there")
# Out:
# love is there

# %%
txt = "i love kbtu"
if "blue" not in txt:
    print("blue is not there")
# Out:
# blue is not there

# %%
a = 'akniet'
print(a[2:5])
# Out:
# nie

# %%
a = 'akniet'
print(a[:5])
# Out:
# aknie

# %%
a = 'akniet'
print(a[-4:-1])
# Out:
# nie

# %%
a = 'akniet'
print(a.upper())
# Out:
# AKNIET

# %%
a = 'AKNIET'
print(a.lower())
# Out:
# akniet

# %%
a = '  akniet  '
print(a.strip())
# Out:
# akniet

# %%
a = 'skniet'
print(a.replace('s', 'a'))
# Out:
# akniet

# %%
a = 'Hello, World!'
print(a.split(" , "))
# Out:
# ['Hello, World!']

# %%
a = "hello"
b = "akniet"
c = a + " " + b
print(c)
# Out:
# hello akniet

# %%
age = 18
txt = f"i am {age}"
print(txt)
# Out:
# i am 18

# %%
price = 59
txt = f"the price is {price:.2f} dollars"
print(txt)
# Out:
# the price is 59.00 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
txt = "my name is \"akniet\" "
print(txt)
# Out:
# my name is "akniet"
